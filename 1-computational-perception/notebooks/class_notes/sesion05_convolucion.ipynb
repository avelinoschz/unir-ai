# %% [markdown]
# # Convolución

# %% [markdown]
# 1. Convolution Operations
# 2. Blurring
# 3. Denoising
# 4. Sharpening

# %%
# Our Setup, Import Libaries, Create our Imshow Function and Download our Images
import cv2
import numpy as np
from matplotlib import pyplot as plt


# Define our imshow function 
def imshow(title = "Image", image = None, size = 10):
    w, h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size * aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %% [markdown]
# ## Convolución

# %% [markdown]
# https://www.youtube.com/watch?v=yb2tPt0QVPY

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Tipos de Filtros
# 1. Filtros Lineales. Transforman cada píxel como una combinación lineal de los valores de píxeles vecinos, utilizando una máscara (kernel).
# Ejemplos:
# Filtro Promedio: Calcula el promedio de los valores dentro de un área definida por el kernel, útil para suavizar.
# Filtro Gaussiano: Utiliza una máscara con valores ponderados según una distribución gaussiana; ideal para eliminar ruido de alta frecuencia.
# Filtro de Derivada (Sobel, Prewitt): Detecta bordes al calcular derivadas en una dirección específica.
# 2. Filtros No Lineales. Transforman los valores de píxeles en una ventana según operaciones no lineales, como ordenar o encontrar valores estadísticos.
# Ejemplos:
# Filtro de Mediana: Reemplaza el valor de un píxel con la mediana de la ventana; muy eficaz contra ruido impulsivo.
# Filtro de Moda: Sustituye el valor del píxel por el valor más frecuente dentro de la ventana.
# Filtro Min/Max: Reemplaza el valor con el mínimo o máximo de la ventana; puede usarse para detección de sombras o destacar objetos brillantes.
# 3. Filtros Basados en la Frecuencia. Operan en el dominio de frecuencia, transformando la imagen mediante transformadas (como Fourier).
# Ejemplos:
# Filtro Pasa Baja: Atenúa las frecuencias altas (bordes, ruido) para suavizar la imagen.
# Filtro Pasa Alta: Atenúa frecuencias bajas y resalta bordes y detalles.

# %% [markdown]
# 4,6,2,2,1,3,1,5,7
# 1,1,2,2,3,4,5,6,7
# Numpy: mediana, moda, max, min
# No lineales
# Medidas de desempeño
# MSE, Peak siganl to noise ratio PSNR o Structural Similarity Index SSIM

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#imagen = cv2.imread('../imagenes/lena_color_512.tif')
imagen=cv2.imread('flowers.jpeg',cv2.IMREAD_GRAYSCALE)
kernel_sharpening = np.array([[ 1/9, 1/9,  1/9],
                               [1/9, 1/9,  1/9],
                               [ 1/9, 1/9,  1/9]])

# Aplicamos el filtro de sharpening
imagen_sharpened = cv2.filter2D(imagen, -1, kernel_sharpening)

# Mostrar resultados
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB))
plt.title("Original")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(imagen_sharpened, cv2.COLOR_BGR2RGB))
plt.title("Sharpening")
plt.axis('off')

plt.show()

# %% [markdown]
# ### **Blurring using Convolutions**

# %% [raw]
# cv2.filter2D, utiliza los siguientes parámetros:
# image: Este es el primer parámetro y representa la imagen de entrada sobre la que se aplicará el filtro. La imagen puede estar en escala de grises o en color (BGR).
#
# ddepth: El segundo parámetro es -1 en este caso. Este parámetro define la profundidad de la imagen de salida. Los valores posibles incluyen:
#
# -1: Significa que la profundidad de la imagen de salida será la misma que la de la imagen de entrada.
# cv2.CV_8U, cv2.CV_16U, cv2.CV_32F, etc.: Puedes especificar una profundidad diferente si lo deseas.
# kernel: El tercer parámetro es kernel_3x3, que es una matriz (o kernel) utilizada para la convolución.

# %%
import cv2
import numpy as np

image = cv2.imread('../imagenes/flowers.jpeg')
imshow('Original Image', image)

# Creando un kernel de 3x3
kernel_3x3 = np.ones((3, 3), np.float32) / 9

# Se utiliza cv2.fitler2D para convolucionar la imagen con el kernel 
blurred = cv2.filter2D(image, -1, kernel_3x3)
imshow('3x3 Kernel Blurring', blurred)

# Creating our 7 x 7 kernel
kernel_7x7 = np.ones((7, 7), np.float32) / 49

blurred2 = cv2.filter2D(image, -1, kernel_7x7)
imshow('7x7 Kernel Blurring', blurred2)

# %% [markdown]
# ### **Other commonly used blurring methods in OpenCV**
# - Regular Blurring
# - Gaussian Blurring
# - Median Blurring

# %%
import cv2
import numpy as np

image = cv2.imread('../imagenes/flowers.jpeg')

# Averaging done by convolving the image with a normalized box filter. 
# This takes the pixels under the box and replaces the central element
# Box size needs to odd and positive 
blur = cv2.blur(image, (5,5))
imshow('Averaging', blur)

# Instead of box filter, gaussian kernel
Gaussian = cv2.GaussianBlur(image, (5,5), 0)
imshow('Gaussian Blurring', Gaussian)

# Takes median of all the pixels under kernel area and central 
# element is replaced with this median value
median = cv2.medianBlur(image, 5)
imshow('Median Blurring', median)
